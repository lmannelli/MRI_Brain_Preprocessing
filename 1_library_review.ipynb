# %%
# %matplotlib inline

import os
from help_functions import *

import ants
import SimpleITK as sitk

print(f'AntsPy version = {ants.__version__}')
print(f'SimpleITK version = {sitk.__version__}')
# Out:
# AntsPy version = 0.4.2
# SimpleITK version = 2.3.1

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
print(f'project folder = {BASE_DIR}')
# Out:
# project folder = c:\Users\Windows\Desktop\GBM_Segmentation

# %%
raw_img_path = os.path.join(BASE_DIR, 'Brain_Extraction', 'sub-01', 'anat', 'sub-01_T1w.nii')
print(f'raw_img_path = {raw_img_path}')
# Out:
# raw_img_path = c:\Users\Windows\Desktop\GBM_Segmentation\Brain_Extraction\sub-01\anat\sub-01_T1w.nii

# %% [markdown]
# AntsPY

# %%
raw_img_ants = ants.image_read(raw_img_path)

# %%
print(raw_img_ants)
# Out:
# ANTsImage (LPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (208, 300, 320)
# 	 Spacing    : (0.8, 0.8, 0.8)
# 	 Origin     : (79.5096, 98.5118, -157.9496)
# 	 Direction  : [-0.9994  0.0341 -0.0108 -0.0343 -0.9992  0.0195 -0.0101  0.0199  0.9998]

# %%
raw_img_ants_arr = raw_img_ants.numpy()

print(f'type = {type(raw_img_ants_arr)}')
print(f'shape = {raw_img_ants_arr.shape}')
# Out:
# type = <class 'numpy.ndarray'>
# shape = (208, 300, 320)

# %%
ants.plot(raw_img_ants, figsize=3, axis=2)

# %%
explore_3D_array(raw_img_ants_arr)
# Out:
# interactive(children=(IntSlider(value=103, description='SLICE', max=207), Output()), _dom_classes=('widget-int…

# %% [markdown]
# Simple ITK

# %%
raw_img_sitk = sitk.ReadImage(raw_img_path, sitk.sitkFloat32)

# %%
#print(raw_img_sitk)

# %%
show_sitk_img_info(raw_img_sitk)
# Out:
#  Pixel Type : 32-bit float
#  Dimensions : (208, 300, 320)
#  Spacing : (0.7999950647354126, 0.800000011920929, 0.800000011920929)
#  Origin : (79.5096435546875, 98.51181030273438, -157.94960021972656)
#  Direction : (-0.9993611786667107, 0.03407792951441396, -0.010767046810889856, -0.03428365283183102, -0.9992211501832022, 0.01953776181988458, -0.010092855016756077, 0.01989441495920183, 0.9997511423179478)

# %%
raw_img_sitk_arr = sitk.GetArrayFromImage(raw_img_sitk)

print(f'type = {type(raw_img_sitk_arr)}')
print(f'shape = {raw_img_sitk_arr.shape}')
# Out:
# type = <class 'numpy.ndarray'>
# shape = (320, 300, 208)

# %%
#sitk.Show(raw_img_sitk)

# %%
explore_3D_array(raw_img_sitk_arr)
# Out:
# interactive(children=(IntSlider(value=159, description='SLICE', max=319), Output()), _dom_classes=('widget-int…
